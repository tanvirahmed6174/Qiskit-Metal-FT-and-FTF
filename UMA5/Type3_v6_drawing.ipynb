# %%
# %reload_ext autoreload
# %autoreload 2
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
import pyEPR as epr
# %metal_heading Good news: Qiskit Metal works fine!


from qiskit_metal.qlibrary.qubits.transmon_cross_tanvir_mod_v1 import TransmonCross_mod
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.qubits.transmon_cross_digitized_claw import TransmonCross
from qiskit_metal.qlibrary.lumped.cap_n_interdigital import CapNInterdigital
from qiskit_metal import draw, Dict
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond

from qiskit_metal.qlibrary.qubits.transmon_pocket_cl_fl import TransmonPocketCL_FL 
from qiskit_metal.qlibrary.qubits.transmon_cross_fl_cl_tanvir_mod import TransmonCrossFL_CL_Tanvir


design = metal.designs.DesignPlanar()

design.chips.main.size['size_x'] = '5mm'
design.chips.main.size['size_y'] = '5mm'
design.chips.main.size['size_z'] = '-350um'
gui = MetalGUI(design)
design.overwrite_enabled = True

design_var = 0  # 0 if doing HFSS simulation

if design_var:
    cpw_width_10 = '10um'
    cpw_gap_6 = '6 um'
    cpw_width_5 = '5 um'
    cpw_gap_3 = '3um'
else:
    cpw_width_10 = '10.9um'
    cpw_gap_6 = '5.1um'
    cpw_width_5 = '5.9um'
    cpw_gap_3 = '2.1um'
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Good news: Qiskit Metal works fine! <h1>

# %%
pos_list = [-0.9,0,0.9]

# launch_ne = LaunchpadWirebond(design, 'Launch_NE_up',options = dict( pos_x=' -1.1250mm', pos_y = '%smm'%(pos_list[1]+1.954),trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=270))
# launch_ne2 = LaunchpadWirebond(design, 'Launch_NE_down',options = dict( pos_x=' +1.1250mm', pos_y = '%smm'%(pos_list[1]-1.954),trace_width='5.9um',trace_gap='2.1um', pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=90))

# launch_ne = LaunchpadWirebond(design, 'Launch_NE_up',options = dict( pos_x=' -.375mm', pos_y = '%smm'%(pos_list[1]+1.954),trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=270))
launch_ne2 = LaunchpadWirebond(design, 'Launch_NE_down',options = dict( pos_x=' +.375mm', pos_y = '%smm'%(pos_list[1]-1.954),trace_width='5.9um',trace_gap='2.1um', pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=90))

# launch_flux_Q3 = LaunchpadWirebond(design, 'Launch_Flux_Q3',options = dict(pos_x='-0.38mm',pos_y = '%smm'%(pos_list[1]+1.954), trace_width='5.9um',trace_gap='2.1um', pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=270))

# launch_nw3 = dict( pos_x='0.375mm',pos_y='%smm'%(pos_list[1]-1.954),trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='90', lead_length='30um')
# lc3 = LaunchpadWirebond(design, 'Launch_Flux_Q1', options = launch_nw3)

launch_flux_options4 = dict( pos_x='1.954mm',pos_y='-1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
launch_flux_options5 = dict( pos_x='1.954mm',pos_y='0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
launch_flux_options6 = dict( pos_x='1.954mm',pos_y='1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
lf4 = LaunchpadWirebond(design, 'Launch_Charge_Q1', options = launch_flux_options4)
lf5 = LaunchpadWirebond(design, 'Launch_Feed3', options = launch_flux_options5)
lf6 = LaunchpadWirebond(design, 'Launch_Charge_Q4', options = launch_flux_options6)



launch_flux_options1 = dict( pos_x='-1.954mm',pos_y='-1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
launch_flux_options2 = dict( pos_x='-1.954mm',pos_y='0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
launch_flux_options3 = dict( pos_x='-1.954mm',pos_y='1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
lf1 = LaunchpadWirebond(design, 'Launch_Charge_Q2', options = launch_flux_options1)
lf2 = LaunchpadWirebond(design, 'Launch_Feed4', options = launch_flux_options2)
lf3 = LaunchpadWirebond(design, 'Launch_Charge_Q3', options = launch_flux_options3)

launch_flux_options7 = dict( pos_x='1.954mm',pos_y='-0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
launch_flux_options8 = dict( pos_x='-1.954mm',pos_y='-0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
lf1 = LaunchpadWirebond(design, 'Launch_Feed1', options = launch_flux_options7)
lf2 = LaunchpadWirebond(design, 'Launch_Feed2', options = launch_flux_options8)

gui.rebuild()
gui.autoscale()

# %%
Q1 = TransmonPocketCL_FL(design, 'Q1', options = dict( pos_x = .28, pos_y=' -1.52 mm', orientation='90',
                                                            connection_pads=dict(
                                    a = dict(pad_gap='20um', loc_W=+1.2, loc_H=-1, pad_width='15.9um',pad_height = '30.9um', cpw_extend = '5um ',pad_cpw_shift = '10um',cpw_width ='10.9um', cpw_gap = '5.1um',pocket_rise = '10um'),
                                    
                                    #b = dict(loc_W=-1, loc_H=+1, pad_width='125um', cpw_extend = '50um', pad_height='60um'),
                                    #c = dict(loc_W=+1, loc_H=+1, pad_width='110um', cpw_extend = '50um')
    ),
    pad_width='80 um', pad_height='90um', pad_gap='140um', inductor_width='10um',
    pocket_width='240um', pocket_height='375um', 
    cl_pocket_edge = '90',
    cl_off_center = '0um',
    cl_gap='2.1um', cl_width='5.9um',
    cl_length='0um',cl_ground_gap = '37um',
    make_FL = True,
     fl_options = dict(t_shift='0um', t_offset='105um',t_width='5.9um',t_gap='2.1um')))


TQ1 = CoupledLineTee(design, 'TQ1', options=dict(pos_x='.36 mm',
                                             pos_y='-.1mm',
                                              coupling_length='390um', coupling_space='4.9um',
                                                        #coupling_space = '4.9um',
                                                        prime_width =cpw_width_10,
                                                        prime_gap =cpw_gap_6,
                                                        second_width =cpw_width_10,
                                                        second_gap =cpw_gap_6,
                                                        down_length ='70um',
                                                        fillet = "20um",
                                                        mirror = False,
                                                        open_termination = False, orientation = 0))






read_q1 = RouteMeander(design,'Read_Q1', options = dict(hfss_wire_bonds = False, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q1',
                                                    pin='a'),
                                                end_pin=Dict(
                                                    component='TQ1',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = '100um',
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "60um",  
                                            total_length = '3.53mm', trace_width = cpw_width_10, trace_gap =cpw_gap_6))


gui.rebuild()
gui.autoscale()
# Out:
# 01:37AM 22s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 01:37AM 22s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
from qiskit_metal.qlibrary.qubits.transmon_cross_fl_cl_tanvir_mod import TransmonCrossFL_CL_Tanvir
Transmon_width = '45um'
Transmon_gap = '35um'#0.005#'6um'''
orientation = '90'
pos_x = -0.2#'-0.20 mm'
pos_y = -1.6 #'-1.3 mm'

pos_x_digitizer = pos_x #'0 mm'

pos_y_digitizer = pos_y + 0.735#'0.298 mm'

cross_length = '250 um'
finger_length = '180um'

orientation = 0



# Q2 = TransmonCross(design, 'Q2', options = dict(make_extra_rect=False, make_fl=False, pos_x = pos_x, pos_y=pos_y, orientation=orientation, 
#                                                      cross_length=cross_length, cross_width=Transmon_width, cross_gap=Transmon_gap))
Q2 = TransmonCrossFL_CL_Tanvir(design, 'Q2', options = dict(make_extra_rect=False, make_fl=False, pos_x = pos_x, pos_y=pos_y, orientation=orientation, 
                                                     cross_length=cross_length, cross_width=Transmon_width, cross_gap=Transmon_gap,
                                                      cl_options= dict(c_offset='25um', c_ground_gap='40um', c_width='5.9um', 
                                                                  c_gap='2.1um', translate_x='-80um', translate_y='0um',  c_angle='270'),))

T_Q2 = CapNInterdigital(design, 'T_Q2', options=dict(pos_x=pos_x_digitizer,
                                             pos_y=pos_y_digitizer,
                                            orientation=orientation, finger_count='7', finger_length=finger_length, cap_gap='35um', cap_width=Transmon_width,
                                                           prime_width ='10um',
                                                        prime_gap ='50um',
                                                        second_width =Transmon_width,
                                                        second_gap ='50um',
                                                        north_width='10.9um',
                                                        north_gap='6um',
                                                        south_width=Transmon_width,
                                                        south_gap=Transmon_gap,
                                                        cap_distance = Transmon_gap,
                                                        cap_gap_ground =Transmon_gap,      
                                                        open_termination=False))
Connect_Q2 = RoutePathfinder(design,'Connect_Q2', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q2',
                                                    pin='connect'),
                                                end_pin=Dict(
                                                    component='T_Q2',
                                                    pin='south_end')),
                                            lead=Dict(
                                                start_straight='0um',
                                                end_straight = '0um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '0 um',
                                            trace_width = Transmon_width,
                                            trace_gap = Transmon_gap,
                                            #anchors = anchors
                                            ))

gui.rebuild()
gui.autoscale()
# Out:
# 01:37AM 23s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
TQ2 = CoupledLineTee(design, 'TQ2', options=dict(pos_x='-.6 mm',
                                             pos_y='-.1mm',
                                              coupling_length='420um', coupling_space='4.9um',
                                                        #coupling_space = '4.9um',
                                                        prime_width =cpw_width_10,
                                                        prime_gap =cpw_gap_6,
                                                        second_width =cpw_width_10,
                                                        second_gap =cpw_gap_6,
                                                        down_length ='70um',
                                                        fillet = "20um",
                                                        mirror = False,
                                                        open_termination = False, orientation = 0))






read_q2 = RouteMeander(design,'Read_Q2', options = dict(hfss_wire_bonds = False, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='T_Q2',
                                                    pin='north_end'),
                                                end_pin=Dict(
                                                    component='TQ2',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "60um",  
                                            total_length = '2.675mm', trace_width = cpw_width_10, trace_gap =cpw_gap_6))


gui.rebuild()
gui.autoscale()
# Out:
# 01:37AM 24s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
charge_line_Q1 = RoutePathfinder(design,'Charge_Line_Q1', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q1',
                                                    pin='Charge_Line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q1',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '150um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))

charge_line_Q2 = RoutePathfinder(design,'Charge_Line_Q2', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q2',
                                                    pin='charge_line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q2',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '150um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))


flux_line_Q1 = RoutePathfinder(design,'Flux_Line_Q1', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q1',
                                                    pin='flux_line'),
                                                end_pin=Dict(
                                                    component='Launch_NE_down',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='10um',
                                                end_straight = '150um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '29um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))


gui.rebuild()

gui.autoscale()
# Out:
# 01:37AM 25s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
from collections import OrderedDict
jogs = OrderedDict()
jogs[0] = ["L", '80um']
# jogs[1] = ["L", '50um']
# jogs[2] = ["R", '20um']
# jogs[3] = ["R", '50um']

mp_tl_01 = RoutePathfinder(design, 'ML_TL_01', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='Launch_Feed2',
                                                        pin='tie'),
                                                    end_pin=Dict(
                                                        component='TQ2',
                                                        pin='prime_start')),
                                                    fillet = '99um',
                                                     trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='300um',
                                                end_straight = '20um',
                                                     step_size = '0.1mm',
                                                start_jogged_extension = jogs,
                                                # end_jogged_extension = jogs
                                                      
                                                  ),
                                            ))



mp_tl_03 = RoutePathfinder(design, 'ML_TL_03', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='TQ1',
                                                        pin='prime_end'),
                                                    end_pin=Dict(
                                                        component='Launch_Feed1',
                                                        pin='tie')),
                                                    fillet = '99um',
                                                              trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '200um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                      trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                                  ),
                                            ))

mp_tl_02 = RoutePathfinder(design, 'ML_TL_02', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='TQ2',
                                                        pin='prime_end'),
                                                    end_pin=Dict(
                                                        component='TQ1',
                                                        pin='prime_start')),
                                                    fillet = '99um',
                                                              trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                      trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                                  ),
                                            ))


gui.rebuild()
gui.autoscale()
# Out:
# 01:37AM 26s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
## Repeat the other symmetric part

design.overwrite_enabled = True
from qiskit_metal.qlibrary.qubits.transmon_pocket_cl_fl_c import TransmonPocketCL_FL
    
Q3 = TransmonPocketCL_FL(design, 'Q3', options = dict( pos_x = -.28, pos_y=' +1.52 mm', orientation='270',
                                                            connection_pads=dict(
                                    a = dict(pad_gap='20um', loc_W=+1.2, loc_H=-1, pad_width='15um',pad_height = '30um', cpw_extend = '5um ',pad_cpw_shift = '10um',cpw_width ='10.9um', cpw_gap = '5.1um',pocket_rise = '10um'),
                                    
                                    #b = dict(loc_W=-1, loc_H=+1, pad_width='125um', cpw_extend = '50um', pad_height='60um'),
                                    #c = dict(loc_W=+1, loc_H=+1, pad_width='110um', cpw_extend = '50um')
    ),
    pad_width='80 um', pad_height='90um', pad_gap='140um', inductor_width='10um',
    pocket_width='240um', pocket_height='375um', 
    cl_pocket_edge = '90',
    cl_off_center = '0um',
    cl_gap='2.1um', cl_width='5.9um',
    cl_length='0um',cl_ground_gap = '37um',
    make_FL = False,
     fl_options = dict(t_shift='0um', t_offset='305um',t_width='5.9um',t_gap='2.1um')))


TQ3 = CoupledLineTee(design, 'TQ3', options=dict(pos_x='-.36 mm',
                                             pos_y='+.1mm',
                                              coupling_length='390um', coupling_space='4.9um',
                                                        #coupling_space = '4.9um',
                                                        prime_width =cpw_width_10,
                                                        prime_gap =cpw_gap_6,
                                                        second_width =cpw_width_10,
                                                        second_gap =cpw_gap_6,
                                                        down_length ='70um',
                                                        fillet = "20um",
                                                        mirror = False,
                                                        open_termination = False, orientation = 180))






read_q3 = RouteMeander(design,'Read_Q3', options = dict(hfss_wire_bonds = False, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q3',
                                                    pin='a'),
                                                end_pin=Dict(
                                                    component='TQ3',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = '100um',
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "60um",  
                                            total_length = '4.03mm', trace_width = cpw_width_10, trace_gap =cpw_gap_6))


gui.rebuild()
gui.autoscale()
# Out:
# 01:37AM 27s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 01:37AM 27s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 01:37AM 28s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
from qiskit_metal.qlibrary.qubits.transmon_cross_fl_cl_tanvir_mod import TransmonCrossFL_CL_Tanvir
Transmon_width = '45um'
Transmon_gap = '35um'#0.005#'6um'''
orientation = '90'
pos_x = 0.2#'-0.20 mm'
pos_y = 1.6 #'-1.3 mm'

pos_x_digitizer = pos_x #'0 mm'

pos_y_digitizer = pos_y - 0.735#'0.298 mm'

cross_length = '250 um'
finger_length = '180um'

orientation = 180



# Q2 = TransmonCross(design, 'Q2', options = dict(make_extra_rect=False, make_fl=False, pos_x = pos_x, pos_y=pos_y, orientation=orientation, 
#                                                      cross_length=cross_length, cross_width=Transmon_width, cross_gap=Transmon_gap))
Q4 = TransmonCrossFL_CL_Tanvir(design, 'Q4', options = dict(make_extra_rect=False, make_fl=False, pos_x = pos_x, pos_y=pos_y, orientation=orientation, 
                                                     cross_length=cross_length, cross_width=Transmon_width, cross_gap=Transmon_gap,
                                                      cl_options= dict(c_offset='25um', c_ground_gap='40um', c_width='5.9um', 
                                                                  c_gap='2.1um', translate_x='+80um', translate_y='-70um',  c_angle='90'),))

T_Q4 = CapNInterdigital(design, 'T_Q4', options=dict(pos_x=pos_x_digitizer,
                                             pos_y=pos_y_digitizer,
                                            orientation=orientation, finger_count='7', finger_length=finger_length, cap_gap='35um', cap_width=Transmon_width,
                                                           prime_width ='10um',
                                                        prime_gap ='50um',
                                                        second_width =Transmon_width,
                                                        second_gap ='50um',
                                                        north_width='10.9um',
                                                        north_gap='6um',
                                                        south_width=Transmon_width,
                                                        south_gap=Transmon_gap,
                                                        cap_distance = Transmon_gap,
                                                        cap_gap_ground =Transmon_gap,      
                                                        open_termination=False))
Connect_Q4 = RoutePathfinder(design,'Connect_Q4', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q4',
                                                    pin='connect'),
                                                end_pin=Dict(
                                                    component='T_Q4',
                                                    pin='south_end')),
                                            lead=Dict(
                                                start_straight='0um',
                                                end_straight = '0um',
                                                
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '0 um',
                                            trace_width = Transmon_width,
                                            trace_gap = Transmon_gap,
                                            #anchors = anchors
                                            ))

gui.rebuild()
gui.autoscale()
# Out:
# 01:37AM 29s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 01:37AM 30s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
TQ4 = CoupledLineTee(design, 'TQ4', options=dict(pos_x='.6 mm',
                                             pos_y='.1mm',
                                              coupling_length='420um', coupling_space='4.9um',
                                                        #coupling_space = '4.9um',
                                                        prime_width =cpw_width_10,
                                                        prime_gap =cpw_gap_6,
                                                        second_width =cpw_width_10,
                                                        second_gap =cpw_gap_6,
                                                        down_length ='70um',
                                                        fillet = "20um",
                                                        mirror = False,
                                                        open_termination = False, orientation = 180))






read_q4 = RouteMeander(design,'Read_Q4', options = dict(hfss_wire_bonds = False, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='T_Q4',
                                                    pin='north_end'),
                                                end_pin=Dict(
                                                    component='TQ4',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "60um",  
                                            total_length = '3.175mm', trace_width = cpw_width_10, trace_gap =cpw_gap_6))


gui.rebuild()
gui.autoscale()
# Out:
# 01:37AM 32s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 01:37AM 32s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
charge_line_Q3 = RoutePathfinder(design,'Charge_Line_Q3', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q3',
                                                    pin='Charge_Line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q3',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '150um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))

charge_line_Q4 = RoutePathfinder(design,'Charge_Line_Q4', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q4',
                                                    pin='charge_line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q4',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '150um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))


# flux_line_Q3 = RoutePathfinder(design,'Flux_Line_Q3', options = dict(hfss_wire_bonds = True,
#                                             pin_inputs=Dict(
#                                                 start_pin=Dict(
#                                                     component='Q3',
#                                                     pin='flux_line'),
#                                                 end_pin=Dict(
#                                                     component='Launch_NE_up',
#                                                     pin='tie')),
#                                             lead=Dict(
#                                                 start_straight='10um',
#                                                 end_straight = '150um',
#                                                 #end_jogged_extension = jogs_end
#                                             ),
#                                             fillet = '29um',
#                                             trace_width = '5.9um',
#                                             trace_gap = '2.1um',
#                                             #anchors = anchors
#                                             ))


gui.rebuild()

gui.autoscale()
# Out:
# 11:58AM 29s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 11:58AM 29s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
from collections import OrderedDict
jogs = OrderedDict()
jogs[0] = ["R", '80um']
# jogs[1] = ["L", '50um']
# jogs[2] = ["R", '20um']
# jogs[3] = ["R", '50um']

mp_tl_04 = RoutePathfinder(design, 'ML_TL_04', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='Launch_Feed4',
                                                        pin='tie'),
                                                    end_pin=Dict(
                                                        component='TQ3',
                                                        pin='prime_end')),
                                                    fillet = '99um',
                                                     trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='300um',
                                                end_straight = '20um',
                                                     step_size = '0.1mm',
                                                start_jogged_extension = jogs,
                                                # end_jogged_extension = jogs
                                                      
                                                  ),
                                            ))



mp_tl_05 = RoutePathfinder(design, 'ML_TL_05', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='TQ3',
                                                        pin='prime_start'),
                                                    end_pin=Dict(
                                                        component='TQ4',
                                                        pin='prime_end')),
                                                    fillet = '99um',
                                                              trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '200um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                      trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                                  ),
                                            ))

mp_tl_06 = RoutePathfinder(design, 'ML_TL_06', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='TQ4',
                                                        pin='prime_start'),
                                                    end_pin=Dict(
                                                        component='Launch_Feed3',
                                                        pin='tie')),
                                                    fillet = '99um',
                                                              trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '420um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                      trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                                  ),
                                            ))


gui.rebuild()
gui.autoscale()
# Out:
# 11:58AM 33s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 11:58AM 33s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 11:59AM 13s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.gds' not found in 'All Files (*)'.
#
# 11:59AM 13s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.gds' not found in 'All Files (*)'.
#
# 11:59AM 39s WARNING [_import_junction_gds_file]: Not able to find file:"../resources/Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"c:\Users\WANGLAB\Tanvir Files and codes\CR project design\resources".
# ocuments\github\qiskit-metal\qiskit_metal\_gui\styles\metal_dark\rc\transparent.pngING: Could not create pixmap from c:\users\wanglab
#
# ocuments\github\qiskit-metal\qiskit_metal\_gui\styles\metal_dark\rc\transparent.pngING: Could not create pixmap from c:\users\wanglab
