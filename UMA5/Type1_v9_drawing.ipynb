# %%
# %reload_ext autoreload
# %autoreload 2
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
import pyEPR as epr
# %metal_heading Good news: Qiskit Metal works fine!


from qiskit_metal.qlibrary.qubits.transmon_pocket_cl import TransmonPocketCL

from qiskit_metal.qlibrary.qubits.transmon_pocket_cl_fl import TransmonPocketCL_FL
from qiskit_metal.qlibrary.qubits.transmon_cross_fl import TransmonCrossFL
from qiskit_metal.qlibrary.qubits.transmon_cross_fl_cl import TransmonCrossFL_CL
from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross
from qiskit_metal.qlibrary.couplers.tunable_coupler_01 import TunableCoupler01

from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.terminations.short_to_ground import ShortToGround

from qiskit_metal.qlibrary.lumped.cap_n_interdigital import CapNInterdigital
from qiskit_metal.qlibrary.lumped.cap_3_interdigital import Cap3Interdigital
from qiskit_metal.qlibrary.couplers.cap_n_interdigital_tee import CapNInterdigitalTee
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.couplers.line_tee import LineTee
#from qiskit_metal.qlibrary.terminations.launchpad_wb_simplecoupler import LaunchpadWirebondSimple
#from qiskit_metal.qlibrary.terminations.launchpad_wb_coupled import LaunchpadWirebondCoupled

from qiskit_metal.qlibrary.terminations.short_to_ground import ShortToGround
import numpy as np
from collections import OrderedDict

from qiskit_metal.qlibrary.qubits.transmon_cross_ebru_temp import TransmonCross_ebru_temp

from qiskit_metal.qlibrary.qubits.transmon_cross_fl_ebru_temp import TransmonCrossFL_ebru_temp
from qiskit_metal.qlibrary.qubits.transmon_cross_fl_cl_ebru_temp import TransmonCrossFL_CL_ebru_temp

design = metal.designs.DesignPlanar()

design.chips.main.size['size_x'] = '5mm'
design.chips.main.size['size_y'] = '5mm'
design.chips.main.size['size_z'] = '-350um'
gui = MetalGUI(design)

from qiskit_metal.analyses.em.cpw_calculations import guided_wavelength

def find_resonator_length(frequency, line_width, line_gap, N): 
    #frequency in GHz
    #line_width/line_gap in um
    #N -> 2 for lambda/2, 4 for lambda/4
    
    [lambdaG, etfSqrt, q] = guided_wavelength(frequency*10**9, line_width*10**-6,
                                              line_gap*10**-6, 750*10**-6, 200*10**-9)
    return str(lambdaG/N*10**3)+" mm"


# find_resonator_length(7.5, 10, 6, 4)
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Good news: Qiskit Metal works fine! <h1>

# %%
pos_list = [-0.9,0,0.9]

# launch_ne = LaunchpadWirebond(design, 'Launch_NE_up',options = dict( pos_x=' -1.1250mm', pos_y = '%smm'%(pos_list[1]+1.954),trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=270))
# launch_ne2 = LaunchpadWirebond(design, 'Launch_NE_down',options = dict( pos_x=' +1.1250mm', pos_y = '%smm'%(pos_list[1]-1.954),trace_width='5.9um',trace_gap='2.1um', pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=90))
launch_ne2 = LaunchpadWirebond(design, 'Launch_NE_down',options = dict( pos_x=' +.375mm', pos_y = '%smm'%(pos_list[1]-1.954),trace_width='5.9um',trace_gap='2.1um', pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=90))

# launch_flux_Q3 = LaunchpadWirebond(design, 'Launch_Flux_Q3',options = dict(pos_x='-0.38mm',pos_y = '%smm'%(pos_list[1]+1.954), trace_width='5.9um',trace_gap='2.1um', pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',orientation=270))

# launch_nw3 = dict( pos_x='0.375mm',pos_y='%smm'%(pos_list[1]-1.954),trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='90', lead_length='30um')
# lc3 = LaunchpadWirebond(design, 'Launch_Flux_Q1', options = launch_nw3)

launch_flux_options4 = dict( pos_x='1.954mm',pos_y='-1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
launch_flux_options5 = dict( pos_x='1.954mm',pos_y='0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
launch_flux_options6 = dict( pos_x='1.954mm',pos_y='1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
lf4 = LaunchpadWirebond(design, 'Launch_Charge_Q1', options = launch_flux_options4)
lf5 = LaunchpadWirebond(design, 'Launch_Feed3', options = launch_flux_options5)
lf6 = LaunchpadWirebond(design, 'Launch_Charge_Q4', options = launch_flux_options6)



launch_flux_options1 = dict( pos_x='-1.954mm',pos_y='-1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
launch_flux_options2 = dict( pos_x='-1.954mm',pos_y='0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
launch_flux_options3 = dict( pos_x='-1.954mm',pos_y='1.8mm', trace_width='5.9um',trace_gap='2.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
lf1 = LaunchpadWirebond(design, 'Launch_Charge_Q2', options = launch_flux_options1)
lf2 = LaunchpadWirebond(design, 'Launch_Feed4', options = launch_flux_options2)
lf3 = LaunchpadWirebond(design, 'Launch_Charge_Q3', options = launch_flux_options3)

launch_flux_options7 = dict( pos_x='1.954mm',pos_y='-0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='180', lead_length='30um')
launch_flux_options8 = dict( pos_x='-1.954mm',pos_y='-0.6mm', trace_width='10.9um',trace_gap='5.1um',pad_gap='100um',pad_width='160um', pad_gap_x= '96um', pad_gap_y= '100um', pad_height='200um', taper_height='150um',  orientation='0', lead_length='30um')
lf1 = LaunchpadWirebond(design, 'Launch_Feed1', options = launch_flux_options7)
lf2 = LaunchpadWirebond(design, 'Launch_Feed2', options = launch_flux_options8)

gui.rebuild()
gui.autoscale()

# %%
design.overwrite_enabled = True

    
from qiskit_metal.qlibrary.qubits.transmon_cross_fl import TransmonCrossFL
from qiskit_metal.qlibrary.qubits.transmon_cross_fl_cl import TransmonCrossFL_CL
from qiskit_metal.qlibrary.qubits.transmon_pocket_cl_fl import TransmonPocketCL_FL #location: C:\Users\WANGLAB\Documents\GitHub\qiskit-metal\qiskit_metal\qlibrary\qubits



Q1 = TransmonPocketCL_FL(design, 'Q1', options = dict( pos_x = '0.76mm', pos_y=' -1.3 mm', orientation='90',
                                                            connection_pads=dict(
                                    a = dict(pad_gap='50um', loc_W=+1.2, loc_H=-1, pad_width='15.9um',pad_height = '30.9um', cpw_extend = '5um ',pad_cpw_shift = '10um',cpw_width ='10.9um', cpw_gap = '5.1um',pocket_rise = '10um'),
                                    
                                    #b = dict(loc_W=-1, loc_H=+1, pad_width='125um', cpw_extend = '50um', pad_height='60um'),
                                    #c = dict(loc_W=+1, loc_H=+1, pad_width='110um', cpw_extend = '50um')
    ),
    pad_width='80um', pad_height='90um', pad_gap='140um', inductor_width='10um',
    pocket_width='240um', pocket_height='375um', 
    cl_pocket_edge = '90',
    cl_off_center = '0um',
    cl_gap='2.1um', cl_width='5.9um',
    cl_length='0um',cl_ground_gap = '37um',
     fl_options = dict(t_shift='0um', t_offset='105um',t_width='5.9um',t_gap='2.1um')))
                                                 

Q2 = TransmonCrossFL_CL_ebru_temp(design, 'Q2', options = dict(make_extra_rect=False, make_fl=False, pos_x = '0.32mm', pos_y=' -1.3 mm', orientation=90, 
                                                     cross_length='170.9um', cross_width='40.9um', cross_gap='30um',
                                                    
                                                 connection_pads = dict(
                                                     readout = dict(connector_location = '180', lead_gap='5.1um',
                                                     claw_length='140um', claw_width='35.9um', ground_spacing='0um', 
                                                                    claw_gap='5.1um', lead_width='10.9um', lead_length='260um')),#claw_length ='115um', claw_width='25um', claw_gap='7um',ground_spacing='3um')),
                                                 fl_options = dict(t_shift='-100um' , t_offset='0um', t_inductive_gap='4.5um', 
                                                                   t_top='10.5um', t_width='5.9um', t_gap='2.1um'),
                                                 cl_options= dict(c_offset='30um', c_ground_gap='38um', c_width='5.9um', 
                                                                  c_gap='2.1um', translate_x='-150um', translate_y='-50um',  c_angle='270'),
                                                 rect_options= dict(rect_width='40um', rect_length='8um')))


gui.rebuild()
gui.autoscale()
# Out:
# 12:09PM 29s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 12:09PM 30s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
TQ1 = CoupledLineTee(design, 'TQ1', options=dict(pos_x='0.79mm',
                                             pos_y='-0.1mm',
                                              coupling_length='390um', coupling_space='4.9um',
                                                        #coupling_space = '4.9um',
                                                        prime_width ='10.9um',
                                                        prime_gap ='5.1um',
                                                        second_width ='10.9um',
                                                        second_gap ='5.1um',
                                                        down_length ='70um',
                                                        fillet = "50um",
                                                        mirror = False,
                                                        open_termination = False, orientation = 0))


read_q1 = RouteMeander(design,'Read_Q1', options = dict(hfss_wire_bonds = True, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q1',
                                                    pin='a'),
                                                end_pin=Dict(
                                                    component='TQ1',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '70um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "160um",  
                                            total_length = '3.45mm', trace_width = '10.9um', trace_gap = '5.1um'))

gui.rebuild()
gui.autoscale()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 TQ1 = CoupledLineTee(design, 'TQ1', options=dict(pos_x='0.79mm',
#       2                                              pos_y='-0.1mm',
#       3                                               coupling_length='390um', coupling_space='4.9um',
#       4                                                         #coupling_space = '4.9um',
#       5                                                         prime_width ='10.9um',
#       6                                                         prime_gap ='5.1um',
#       7                                                         second_width ='10.9um',
#       8                                                         second_gap ='5.1um',
#       9                                                         down_length ='70um',
#      10                                                         fillet = "50um",
#      11                                                         mirror = False,
#      12                                                         open_termination = False, orientation = 0))
#      15 read_q1 = RouteMeander(design,'Read_Q1', options = dict(hfss_wire_bonds = True,
#      16                                             pin_inputs=Dict(
#      17                                                 start_pin=Dict(
#    (...)
#      33                                             spacing = "160um",
#      34                                             total_length = '3.45mm', trace_width = '10.9um', trace_gap = '5.1um'))
#      36 gui.rebuild()
#
# NameError: name 'CoupledLineTee' is not defined

# %%
TQ2 = CoupledLineTee(design, 'TQ2', options=dict(pos_x='-.85mm',
                                             pos_y='-1.3mm',
                                              coupling_length='130um', coupling_space='4.9um',
                                                  prime_width ='10.9um',
                                                        prime_gap ='5.1um',
                                                        second_width ='10.9um',
                                                        second_gap ='5.1um', open_termination=False, orientation = 180))





read_q2 = RouteMeander(design,'Read_Q2', options = dict(hfss_wire_bonds = False, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q2',
                                                    pin='readout'),
                                                end_pin=Dict(
                                                    component='TQ2',
                                                    pin='prime_start')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "120um",  
                                            total_length = '2.88mm', trace_width = '10.9um', trace_gap = '5.1um'))





Tf_q2 = CapNInterdigitalTee(design, 'Tf_q2', options=dict(pos_x='-0.99mm',
                                             pos_y='-0.1mm',
                                            orientation=0, finger_count='12', finger_length='140um', cap_gap='6.1um', cap_width='15.9um',
                                                           prime_width ='10.9um',
                                                        prime_gap ='5.1um',
                                                        second_width ='10.9um',
                                                        second_gap ='5.1um',
                                                 open_termination=False))

purcell_q2 = RouteMeander(design,'Purcell_Q2', options = dict(hfss_wire_bonds = False, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Tf_q2',
                                                    pin='second_end'),
                                                end_pin=Dict(
                                                    component='TQ2',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "160um",  
                                            total_length = '2.7mm', trace_width = '10.9um', trace_gap = '5.1um'))



gui.rebuild()
gui.autoscale()
# Out:
# 12:09PM 37s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# ocuments\github\qiskit-metal\qiskit_metal\_gui\styles\metal_dark\rc\transparent.pngING: Could not create pixmap from c:\users\wanglab
#
# ocuments\github\qiskit-metal\qiskit_metal\_gui\styles\metal_dark\rc\transparent.pngING: Could not create pixmap from c:\users\wanglab
#
# 12:10PM 30s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.gds' not found in 'All Files (*)'.
#
# 12:10PM 30s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.gds' not found in 'All Files (*)'.
#
# 12:11PM 05s WARNING [_import_junction_gds_file]: Not able to find file:"../resources/Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"c:\Users\WANGLAB\Tanvir Files and codes\CR project design\resources".

# %%
charge_line_Q1 = RoutePathfinder(design,'Charge_Line_Q1', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q1',
                                                    pin='Charge_Line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q1',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '150um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))

charge_line_Q2 = RoutePathfinder(design,'Charge_Line_Q2', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q2',
                                                    pin='charge_line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q2',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '1550um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))


flux_line_Q1 = RoutePathfinder(design,'Flux_Line_Q1', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q1',
                                                    pin='flux_line'),
                                                end_pin=Dict(
                                                    component='Launch_NE_down',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='150um',
                                                end_straight = '50um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '49um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))


gui.rebuild()

gui.autoscale()
# Out:
# 12:07PM 44s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
from collections import OrderedDict
jogs = OrderedDict()
jogs[0] = ["L", '80um']
# jogs[1] = ["L", '50um']
# jogs[2] = ["R", '20um']
# jogs[3] = ["R", '50um']

mp_tl_01 = RoutePathfinder(design, 'ML_TL_01', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='Launch_Feed2',
                                                        pin='tie'),
                                                    end_pin=Dict(
                                                        component='Tf_q2',
                                                        pin='prime_start')),
                                                    fillet = '99um',
                                                     trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='300um',
                                                end_straight = '20um',
                                                     step_size = '0.1mm',
                                                start_jogged_extension = jogs,
                                                # end_jogged_extension = jogs
                                                      
                                                  ),
                                            ))


mp_tl_02 = RoutePathfinder(design, 'ML_TL_02', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='Tf_q2',
                                                        pin='prime_end'),
                                                    end_pin=Dict(
                                                        component='TQ1',
                                                        pin='prime_start')),
                                                    fillet = '99um',
                                                              trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '200um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                      trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                                  ),
                                            ))

mp_tl_03 = RoutePathfinder(design, 'ML_TL_03', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='TQ1',
                                                        pin='prime_end'),
                                                    end_pin=Dict(
                                                        component='Launch_Feed1',
                                                        pin='tie')),
                                                    fillet = '99um',
                                                              trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '200um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                      trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                                  ),
                                            ))


gui.rebuild()
gui.autoscale()
# Out:
# 12:07PM 45s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# ocuments\github\qiskit-metal\qiskit_metal\_gui\styles\metal_dark\rc\transparent.pngING: Could not create pixmap from c:\users\wanglab
#
# ocuments\github\qiskit-metal\qiskit_metal\_gui\styles\metal_dark\rc\transparent.pngING: Could not create pixmap from c:\users\wanglab

# %% [markdown]
# ## Upper system

# %%
## Repeat the other symmetric part

design.overwrite_enabled = True

    
from qiskit_metal.qlibrary.qubits.transmon_cross_fl import TransmonCrossFL
from qiskit_metal.qlibrary.qubits.transmon_cross_fl_cl import TransmonCrossFL_CL
from qiskit_metal.qlibrary.qubits.transmon_pocket_cl_fl_c import TransmonPocketCL_FL



Q3 = TransmonPocketCL_FL(design, 'Q3', options = dict( pos_x = -.76, pos_y=' +1.3 mm', orientation='270',
                                                            connection_pads=dict(
                                    a = dict(pad_gap='20um', loc_W=+1.2, loc_H=-1, pad_width='15um',pad_height = '30um', cpw_extend = '5um ',pad_cpw_shift = '10um',cpw_width ='10.9um', cpw_gap = '5.1um',pocket_rise = '10um'),
                                    
                                    #b = dict(loc_W=-1, loc_H=+1, pad_width='125um', cpw_extend = '50um', pad_height='60um'),
                                    #c = dict(loc_W=+1, loc_H=+1, pad_width='110um', cpw_extend = '50um')
    ),
    pad_width='80 um', pad_height='90um', pad_gap='140um', inductor_width='10um',
    pocket_width='240um', pocket_height='375um', 
    cl_pocket_edge = '90',
    cl_off_center = '0um',
    cl_gap='2.1um', cl_width='5.9um',
    cl_length='0um',cl_ground_gap = '37um',
    make_FL = False,
     fl_options = dict(t_shift='0um', t_offset='305um',t_width='5.9um',t_gap='2.1um')))

# Q3 = TransmonPocketCL_FL(design, 'Q3', options = dict( pos_x = -.76, pos_y=' 1.3 mm', orientation='270',
#                                                             connection_pads=dict(
#                                     a = dict(pad_gap='20um', loc_W=+1.2, loc_H=-1, pad_width='15.9um',pad_height = '30.9um', cpw_extend = '5um ',pad_cpw_shift = '10um',cpw_width ='10.9um', cpw_gap = '5.1um',pocket_rise = '10um'),
                                    
#                                     #b = dict(loc_W=-1, loc_H=+1, pad_width='125um', cpw_extend = '50um', pad_height='60um'),
#                                     #c = dict(loc_W=+1, loc_H=+1, pad_width='110um', cpw_extend = '50um')
#     ),
#     pad_width='80 um', pad_height='90um', pad_gap='140um', inductor_width='10um',
#     pocket_width='240um', pocket_height='375um', 
#     cl_pocket_edge = '90',
#     cl_off_center = '0um',
#     cl_gap='2.1um', cl_width='5.9um',
#     cl_length='0um',cl_ground_gap = '37um',
#     make_FL = True,
#      fl_options = dict(t_shift='0um', t_offset='105um',t_width='5.9um',t_gap='2.1um')))


Q4 = TransmonCrossFL_CL_ebru_temp(design, 'Q4', options = dict(make_extra_rect=False, make_fl=False, pos_x = '-0.32mm', pos_y=' 1.3 mm', orientation=270, 
                                                     cross_length='170um', cross_width='40um', cross_gap='30um',
                                                    
                                                 connection_pads = dict(
                                                     readout = dict(connector_location = '270', lead_gap='5.1um',
                                                     claw_length='140.9um', claw_width='40.9um', ground_spacing='3.9um', 
                                                                    claw_gap='5.1um', lead_width='10.9um', lead_length='260um')),#claw_length ='115um', claw_width='25um', claw_gap='7um',ground_spacing='3um')),
                                                 fl_options = dict(t_shift='-100um' , t_offset='0um', t_inductive_gap='4.5um', 
                                                                   t_top='10.5um', t_width='5um', t_gap='3um'),
                                                 cl_options= dict(c_offset='30um', c_ground_gap='38um', c_width='5.9um', 
                                                                  c_gap='2.1um', translate_x=' 170um', translate_y='-50um',  c_angle='90'),
                                                 rect_options= dict(rect_width='40um', rect_length='8um')))


gui.rebuild()
gui.autoscale()
# Out:
# 10:38AM 17s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 10:38AM 17s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
TQ3 = CoupledLineTee(design, 'TQ3', options=dict(pos_x='-0.79mm',
                                             pos_y='0.1mm',
                                              coupling_length='400um', coupling_space='4.9um',
                                                  prime_width ='10.9um',
                                                        prime_gap ='5.1um',
                                                        second_width ='10.9um',
                                                        second_gap ='5.1um',open_termination=False, orientation = 180))


read_q3 = RouteMeander(design,'Read_Q3', options = dict(hfss_wire_bonds = True, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q3',
                                                    pin='a'),
                                                end_pin=Dict(
                                                    component='TQ3',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '70um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "160um",  
                                            total_length = '4.05mm', trace_width = '10.9um', trace_gap = '5.1um'))


TQ4 = CoupledLineTee(design, 'TQ4', options=dict(pos_x='.9mm',
                                             pos_y='1.45mm',
                                              coupling_length='130um', coupling_space='4.9um', 
                                                  prime_width ='10.9um',
                                                        prime_gap ='5.1um',
                                                        second_width ='10.9um',
                                                        second_gap ='5.1um',open_termination=False, orientation = 0))





read_q4 = RouteMeander(design,'Read_Q4', options = dict(hfss_wire_bonds = False, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q4',
                                                    pin='readout'),
                                                end_pin=Dict(
                                                    component='TQ4',
                                                    pin='prime_start')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '20um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "160um",  
                                            total_length = '3.4mm', trace_width = '10.9um', trace_gap = '5.1um'))




Tf_q4 = CapNInterdigitalTee(design, 'Tf_q4', options=dict(pos_x='0.99mm',
                                             pos_y='0.1mm',
                                            orientation=180, finger_count='18', finger_length='140um', cap_gap='6.1um', cap_width='15.9um',
                                                           prime_width ='10.9um',
                                                        prime_gap ='5.1um',
                                                        second_width ='10.9um',
                                                        second_gap ='5.1um',
                                                 open_termination=False))

purcell_q4 = RouteMeander(design,'Purcell_Q4', options = dict(hfss_wire_bonds = True, 
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Tf_q4',
                                                    pin='second_end'),
                                                end_pin=Dict(
                                                    component='TQ4',
                                                    pin='second_end')
                                            ),
                                            lead=Dict(
                                                start_straight='50um',
                                                end_straight = '70um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                            ),
                                            meander=Dict(spacing = "100um",
                                                asymmetry = '0um'),
                                            fillet = "49.9um",
                                            spacing = "160um",  
                                            total_length = '2.4mm',trace_width = '10.9um', trace_gap = '5.1um'))

gui.rebuild()
gui.autoscale()
# Out:
# 10:39AM 32s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
# 10:39AM 54s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.gds' not found in 'All Files (*)'.
#
# 10:39AM 54s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: QWindowsNativeFileDialogBase::selectNameFilter: Invalid parameter '*.gds' not found in 'All Files (*)'.
#
# 10:40AM 19s WARNING [_import_junction_gds_file]: Not able to find file:"../resources/Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"c:\Users\WANGLAB\Tanvir Files and codes\CR project design\resources".

# %%
mp_tl_04 = RoutePathfinder(design, 'ML_TL_04', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='Launch_Feed3',
                                                        pin='tie'),
                                                    end_pin=Dict(
                                                        component='Tf_q4',
                                                        pin='prime_start')),
                                                    fillet = '99um',
                                                               trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '200um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                  ),
                                            ))


mp_tl_05 = RoutePathfinder(design, 'ML_TL_05', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='Tf_q4',
                                                        pin='prime_end'),
                                                    end_pin=Dict(
                                                        component='TQ3',
                                                        pin='prime_start')),
                                                    fillet = '99um',
                                                               trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '200um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                  ),
                                            ))

mp_tl_06 = RoutePathfinder(design, 'ML_TL_06', options = dict(hfss_wire_bonds = True,
                                                    pin_inputs = dict(
                                                    start_pin=Dict(
                                                        component='TQ3',
                                                        pin='prime_end'),
                                                    end_pin=Dict(
                                                        component='Launch_Feed4',
                                                        pin='tie')),
                                                    fillet = '99um',
                                                               trace_width = '10.9um',
                                                    trace_gap = '5.1um',
                                                 lead=Dict(
                                                start_straight='30um',
                                                end_straight = '200um',
                                                #start_jogged_extension = jogs_start,
                                                #end_jogged_extension = jogs_end
                                                  ),
                                            ))


gui.rebuild()
gui.autoscale()
# Out:
# 10:39AM 09s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?

# %%
charge_line_Q3 = RoutePathfinder(design,'Charge_Line_Q3', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q3',
                                                    pin='Charge_Line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q3',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '150um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))

charge_line_Q4 = RoutePathfinder(design,'Charge_Line_Q4', options = dict(hfss_wire_bonds = True,
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='Q4',
                                                    pin='charge_line'),
                                                end_pin=Dict(
                                                    component='Launch_Charge_Q4',
                                                    pin='tie')),
                                            lead=Dict(
                                                start_straight='175um',
                                                end_straight = '1450um',
                                                #end_jogged_extension = jogs_end
                                            ),
                                            fillet = '99um',
                                            trace_width = '5.9um',
                                            trace_gap = '2.1um',
                                            #anchors = anchors
                                            ))


# flux_line_Q1 = RoutePathfinder(design,'Flux_Line_Q3', options = dict(hfss_wire_bonds = True,
#                                             pin_inputs=Dict(
#                                                 start_pin=Dict(
#                                                     component='Q3',
#                                                     pin='flux_line'),
#                                                 end_pin=Dict(
#                                                     component='Launch_NE_up',
#                                                     pin='tie')),
#                                             lead=Dict(
#                                                 start_straight='150um',
#                                                 end_straight = '50um',
#                                                 #end_jogged_extension = jogs_end
#                                             ),
#                                             fillet = '49um',
#                                             trace_width = '5.9um',
#                                             trace_gap = '2.1um',
#                                             #anchors = anchors
#                                             ))


gui.rebuild()

gui.autoscale()
# Out:
# 10:39AM 12s INFO [make_connection_pad]: Warning: Did you mean to define a transmon wubit with loc_W and loc_H that are not +1 or -1?? Are you sure you want to do this?
